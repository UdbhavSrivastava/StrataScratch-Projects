# %% [markdown]
# # Chama - Data Transformation

# %% [markdown]
# ## 1. Problem Statement
#
# #### Some event data come as json files and need some transformation to be structured as tables. Convert the case.json file to 3 csv files (Refer the website for further details)
#
# ##### 1. CuratedOfferOptions.csv, 2. DynamicPriceOption.csv, 3. DynamicPriceRange.csv

# %% [markdown]
# ## 2. Data Importation & Exploration

# %%
import pandas as pd
from datetime import datetime
import json
import pytz
df = pd.read_json("case.json")
df.head(10)
# Out:
#            EnqueuedTimeUtc            EventName  \
# 0  2021-09-05 08:04:08 UTC  DynamicPrice_Result
# 1  2021-08-18 11:43:23 UTC  DynamicPrice_Result
# 2  2021-09-05 09:04:04 UTC  DynamicPrice_Result
# 3  2021-08-25 05:02:55 UTC   CurateOffer_Result
# 4  2021-09-05 08:03:28 UTC  DynamicPrice_Result
# 5  2021-08-18 11:44:00 UTC  DynamicPrice_Result
# 6  2021-09-05 08:03:40 UTC  DynamicPrice_Result
# 7  2021-09-05 04:03:08 UTC  DynamicPrice_Result
# 8  2021-08-18 11:44:00 UTC  DynamicPrice_Result
# 9  2021-09-05 09:18:04 UTC  DynamicPrice_Result
#
#                                              Payload
# 0  {"provider":"ApplyDynamicPriceRange","offerId"...
# 1  {"provider":"ApplyDynamicPricePerOption","offe...
# 2  {"provider":"ApplyDynamicPriceRange","offerId"...
# 3  [{"curationProvider":"ByPrice","offerId":"149f...
# 4  {"provider":"ApplyDynamicPriceRange","offerId"...
# 5  {"provider":"ApplyDynamicPricePerOption","offe...
# 6  {"provider":"ApplyDynamicPriceRange","offerId"...
# 7  {"provider":"ApplyDynamicPriceRange","offerId"...
# 8  {"provider":"ApplyDynamicPricePerOption","offe...
# 9  {"provider":"ApplyDynamicPriceRange","offerId"...

# %% [markdown]
# ### 3. CuratedOfferOptions (file 1)

# %%
df_curated = df[df['EventName'] == 'CurateOffer_Result']
df_curated
# Out:
#             EnqueuedTimeUtc           EventName  \
# 3   2021-08-25 05:02:55 UTC  CurateOffer_Result
# 13  2021-08-25 09:03:29 UTC  CurateOffer_Result
# 15  2021-08-25 05:02:18 UTC  CurateOffer_Result
# 17  2021-08-25 09:02:29 UTC  CurateOffer_Result
# 35  2021-08-25 09:03:14 UTC  CurateOffer_Result
#
#                                               Payload
# 3   [{"curationProvider":"ByPrice","offerId":"149f...
# 13  [{"curationProvider":"ByPrice","offerId":"c99a...
# 15  [{"curationProvider":"ByPrice","offerId":"d668...
# 17  [{"curationProvider":"ByPrice","offerId":"0a06...
# 35  [{"curationProvider":"ByPrice","offerId":"135d...

# %%
import pandas as pd
import json

def extract_curation_details(df):
    extracted_data = []

    for index, row in df.iterrows():
        enqueued_time_sp = pd.to_datetime(row['EnqueuedTimeUtc']).strftime('%d/%m/%Y')
        
        payloads = row['Payload']  # Access payload
        if isinstance(payloads, str):  
            try:
                payloads = json.loads(payloads)  # Convert string to JSON
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON at row {index}: {e}")
                continue  # Skip invalid rows
        
        # Ensure payloads is a list
        if isinstance(payloads, dict):  
            payloads = [payloads]  # Convert single object to list
        
        for payload in payloads:
            if not isinstance(payload, dict):
                print(f"Skipping malformed payload at row {index}: {payload}")
                continue  # Skip malformed payloads
            
            curation_provider = payload.get("curationProvider", "")
            offer_id = payload.get("offerId", "")
            dealer_id = payload.get("dealerId", "")

            for option in payload.get("options", []):
                extracted_data.append({
                    "CurationProvider": curation_provider,
                    "OfferId": offer_id,
                    "DealerId": dealer_id,
                    "UniqueOptionId": option.get("uniqueOptionId", ""),
                    "OptionId": option.get("optionId", ""),
                    "IsMobileDealer": option.get("isMobileDealer", False),
                    "IsOpen": option.get("isOpen", False),
                    "Eta": option.get("eta", ""),
                    "ChamaScore": option.get("chamaScore", 0),
                    "ProductBrand": option.get("productBrand", ""),
                    "IsWinner": option.get("isWinner", False),
                    "MinimumPrice": option.get("minimumPrice", 0),
                    "MaximumPrice": option.get("maximumPrice", 0),
                    "DynamicPrice": option.get("dynamicPrice", 0),
                    "FinalPrice": option.get("finalPrice", 0),
                    "DefeatPrimaryReason": option.get("defeatPrimaryReason", ""),
                    "DefeatReasons": option.get("defeatReasons", []),
                    "EnqueuedTimeSP": enqueued_time_sp
                })

    return pd.DataFrame(extracted_data)

df_extracted = extract_curation_details(df_curated)
df_extracted
# Out:
#    CurationProvider                               OfferId DealerId  \
# 0           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     6517
# 1           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     6517
# 2           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     9047
# 3           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     9047
# 4           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     9047
# 5           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     9047
# 6           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     8330
# 7           ByPrice  149f0e53-ff85-425f-a01a-8710f06704ea     8835
# 8           ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     6517
# 9           ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     6517
# 10          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     9047
# 11          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     9047
# 12          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     9047
# 13          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     9047
# 14          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     8330
# 15          ByPrice  c99aa9a7-ac50-4a10-be0f-ac9f5ac0f45d     8835
# 16          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     6517
# 17          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     6517
# 18          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     9047
# 19          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     9047
# 20          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     9047
# 21          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     9047
# 22          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     8330
# 23          ByPrice  d668106a-7596-49c6-b99a-18b7a2f3963f     8835
# 24          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     6517
# 25          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     6517
# 26          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     9047
# 27          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     9047
# 28          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     9047
# 29          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     9047
# 30          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     8330
# 31          ByPrice  0a06a478-77b3-4941-83d3-84ded18d4731     8835
# 32          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     6517
# 33          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     6517
# 34          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     9047
# 35          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     9047
# 36          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     9047
# 37          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     9047
# 38          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     8330
# 39          ByPrice  135d8401-11c0-4d21-bac1-cdb93ba65189     8835
#
#                           UniqueOptionId  \
# 0   b0e296a9-0590-f0e0-8211-243a2ededb12
# 1   d6562c24-0b37-5fb4-8275-65b7b8b47b87
# 2   8d0f9262-f543-d0c8-a869-33985ae3ecda
# 3   3cd346f4-d297-7568-2e50-d43a8e2fd0a9
# 4   577e4bbd-f49d-ac23-56a6-e70072a05229
# 5   f9b876ab-2590-952f-d69d-5b352ec251f3
# 6   151e59ac-761a-96f5-d2b9-882037a9fd28
# 7   b7a7b6d1-4dae-7392-5aaf-f3369c29db1d
# 8   b0e296a9-0590-f0e0-8211-243a2ededb12
# 9   d6562c24-0b37-5fb4-8275-65b7b8b47b87
# 10  8d0f9262-f543-d0c8-a869-33985ae3ecda
# 11  3cd346f4-d297-7568-2e50-d43a8e2fd0a9
# 12  577e4bbd-f49d-ac23-56a6-e70072a05229
# 13  f9b876ab-2590-952f-d69d-5b352ec251f3
# 14  151e59ac-761a-96f5-d2b9-882037a9fd28
# 15  b7a7b6d1-4dae-7392-5aaf-f3369c29db1d
# 16  b0e296a9-0590-f0e0-8211-243a2ededb12
# 17  d6562c24-0b37-5fb4-8275-65b7b8b47b87
# 18  8d0f9262-f543-d0c8-a869-33985ae3ecda
# 19  3cd346f4-d297-7568-2e50-d43a8e2fd0a9
# 20  577e4bbd-f49d-ac23-56a6-e70072a05229
# 21  f9b876ab-2590-952f-d69d-5b352ec251f3
# 22  151e59ac-761a-96f5-d2b9-882037a9fd28
# 23  b7a7b6d1-4dae-7392-5aaf-f3369c29db1d
# 24  b0e296a9-0590-f0e0-8211-243a2ededb12
# 25  d6562c24-0b37-5fb4-8275-65b7b8b47b87
# 26  8d0f9262-f543-d0c8-a869-33985ae3ecda
# 27  3cd346f4-d297-7568-2e50-d43a8e2fd0a9
# 28  577e4bbd-f49d-ac23-56a6-e70072a05229
# 29  f9b876ab-2590-952f-d69d-5b352ec251f3
# 30  151e59ac-761a-96f5-d2b9-882037a9fd28
# 31  b7a7b6d1-4dae-7392-5aaf-f3369c29db1d
# 32  b0e296a9-0590-f0e0-8211-243a2ededb12
# 33  d6562c24-0b37-5fb4-8275-65b7b8b47b87
# 34  8d0f9262-f543-d0c8-a869-33985ae3ecda
# 35  3cd346f4-d297-7568-2e50-d43a8e2fd0a9
# 36  577e4bbd-f49d-ac23-56a6-e70072a05229
# 37  f9b876ab-2590-952f-d69d-5b352ec251f3
# 38  151e59ac-761a-96f5-d2b9-882037a9fd28
# 39  b7a7b6d1-4dae-7392-5aaf-f3369c29db1d
#
#                                         OptionId  IsMobileDealer  IsOpen  \
# 0   6517 || dd839e4c-9f84-45eb-9cb2-9069fecf70f2            True    True
# 1                                   6517 || 6517           False   False
# 2                       9047 || 9047 || ULTRAGAZ           False   False
# 3                       9047 || 9047 || CONSIGAZ           False   False
# 4                       9047 || 9047 || LIQUIGAS           False   False
# 5                    9047 || 9047 || NACIONALGAS           False   False
# 6                       8330 || 8330 || CONSIGAZ           False    True
# 7                       8835 || 8835 || LIQUIGAS           False   False
# 8   6517 || dd839e4c-9f84-45eb-9cb2-9069fecf70f2            True    True
# 9                                   6517 || 6517           False    True
# 10                      9047 || 9047 || ULTRAGAZ           False   False
# 11                      9047 || 9047 || CONSIGAZ           False   False
# 12                      9047 || 9047 || LIQUIGAS           False   False
# 13                   9047 || 9047 || NACIONALGAS           False   False
# 14                      8330 || 8330 || CONSIGAZ           False    True
# 15                      8835 || 8835 || LIQUIGAS           False   False
# 16  6517 || dd839e4c-9f84-45eb-9cb2-9069fecf70f2            True    True
# 17                                  6517 || 6517           False   False
# 18                      9047 || 9047 || ULTRAGAZ           False   False
# 19                      9047 || 9047 || CONSIGAZ           False   False
# 20                      9047 || 9047 || LIQUIGAS           False   False
# 21                   9047 || 9047 || NACIONALGAS           False   False
# 22                      8330 || 8330 || CONSIGAZ           False    True
# 23                      8835 || 8835 || LIQUIGAS           False   False
# 24  6517 || dd839e4c-9f84-45eb-9cb2-9069fecf70f2            True    True
# 25                                  6517 || 6517           False    True
# 26                      9047 || 9047 || ULTRAGAZ           False   False
# 27                      9047 || 9047 || CONSIGAZ           False   False
# 28                      9047 || 9047 || LIQUIGAS           False   False
# 29                   9047 || 9047 || NACIONALGAS           False   False
# 30                      8330 || 8330 || CONSIGAZ           False    True
# 31                      8835 || 8835 || LIQUIGAS           False   False
# 32  6517 || dd839e4c-9f84-45eb-9cb2-9069fecf70f2            True    True
# 33                                  6517 || 6517           False    True
# 34                      9047 || 9047 || ULTRAGAZ           False   False
# 35                      9047 || 9047 || CONSIGAZ           False   False
# 36                      9047 || 9047 || LIQUIGAS           False   False
# 37                   9047 || 9047 || NACIONALGAS           False   False
# 38                      8330 || 8330 || CONSIGAZ           False    True
# 39                      8835 || 8835 || LIQUIGAS           False   False
#
#                  Eta  ChamaScore ProductBrand  IsWinner  MinimumPrice  \
# 0               1:00         8.0     ULTRAGAZ      True         90.00
# 1               0:01         8.0     ULTRAGAZ     False         90.00
# 2               1:00         9.0     ULTRAGAZ     False         99.00
# 3               1:00         9.0     CONSIGAZ     False         89.99
# 4               1:00         9.0     LIQUIGAS     False         92.00
# 5               1:00         9.0  NACIONALGAS      True         88.90
# 6               0:01         8.0     CONSIGAZ      True         80.00
# 7               0:01         8.0     LIQUIGAS      True         60.00
# 8   00:12:54.9215999         8.0     ULTRAGAZ      True         90.00
# 9               0:01         8.0     ULTRAGAZ     False         90.00
# 10              1:00         9.0     ULTRAGAZ     False         99.00
# 11              1:00         9.0     CONSIGAZ     False         89.99
# 12              1:00         9.0     LIQUIGAS     False         92.00
# 13              1:00         9.0  NACIONALGAS      True         88.90
# 14              0:01         8.0     CONSIGAZ      True         80.00
# 15              0:01         8.0     LIQUIGAS      True         60.00
# 16              1:00         8.0     ULTRAGAZ      True         90.00
# 17              0:01         8.0     ULTRAGAZ     False         90.00
# 18              1:00         9.0     ULTRAGAZ     False         99.00
# 19              1:00         9.0     CONSIGAZ     False         89.99
# 20              1:00         9.0     LIQUIGAS     False         92.00
# 21              1:00         9.0  NACIONALGAS      True         88.90
# 22              0:01         8.0     CONSIGAZ      True         80.00
# 23              0:01         8.0     LIQUIGAS      True         60.00
# 24  00:01:27.4607999         8.0     ULTRAGAZ      True         90.00
# 25              0:01         8.0     ULTRAGAZ     False         90.00
# 26              1:00         9.0     ULTRAGAZ     False         99.00
# 27              1:00         9.0     CONSIGAZ     False         89.99
# 28              1:00         9.0     LIQUIGAS     False         92.00
# 29              1:00         9.0  NACIONALGAS      True         88.90
# 30              0:01         8.0     CONSIGAZ      True         80.00
# 31              0:01         8.0     LIQUIGAS      True         60.00
# 32  00:07:11.1911999         8.0     ULTRAGAZ      True         90.00
# 33              0:01         8.0     ULTRAGAZ     False         90.00
# 34              1:00         9.0     ULTRAGAZ     False         99.00
# 35              1:00         9.0     CONSIGAZ     False         89.99
# 36              1:00         9.0     LIQUIGAS     False         92.00
# 37              1:00         9.0  NACIONALGAS      True         88.90
# 38              0:01         8.0     CONSIGAZ      True         80.00
# 39              0:01         8.0     LIQUIGAS      True         60.00
#
#     MaximumPrice  DynamicPrice  FinalPrice DefeatPrimaryReason  \
# 0         180.00         91.90       91.90
# 1         180.00         91.90       91.90              Closed
# 2         198.00         99.95       99.95              Closed
# 3         179.98         91.89       91.89              Closed
# 4         184.00         93.90       93.90              Closed
# 5         177.80         90.80       90.80
# 6         160.00         87.35       87.35
# 7         120.00         87.35       87.35
# 8         180.00         91.90       91.90
# 9         180.00         91.90       91.90    HasDriverInOffer
# 10        198.00         99.95       99.95              Closed
# 11        179.98         91.89       91.89              Closed
# 12        184.00         93.90       93.90              Closed
# 13        177.80         90.80       90.80
# 14        160.00         87.35       87.35
# 15        120.00         87.35       87.35
# 16        180.00         91.90       91.90
# 17        180.00         91.90       91.90              Closed
# 18        198.00         99.95       99.95              Closed
# 19        179.98         91.89       91.89              Closed
# 20        184.00         93.90       93.90              Closed
# 21        177.80         90.80       90.80
# 22        160.00         87.35       87.35
# 23        120.00         87.35       87.35
# 24        180.00         91.90       91.90
# 25        180.00         91.90       91.90    HasDriverInOffer
# 26        198.00         99.95       99.95              Closed
# 27        179.98         91.89       91.89              Closed
# 28        184.00         93.90       93.90              Closed
# 29        177.80         90.80       90.80
# 30        160.00         87.35       87.35
# 31        120.00         87.35       87.35
# 32        180.00         91.90       91.90
# 33        180.00         91.90       91.90    HasDriverInOffer
# 34        198.00         99.95       99.95              Closed
# 35        179.98         91.89       91.89              Closed
# 36        184.00         93.90       93.90              Closed
# 37        177.80         90.80       90.80
# 38        160.00         87.35       87.35
# 39        120.00         87.35       87.35
#
#                                         DefeatReasons EnqueuedTimeSP
# 0                                                  []     25/08/2021
# 1                          [Closed, HasDriverInOffer]     25/08/2021
# 2             [Closed, HigherPrice, HasDriverInOffer]     25/08/2021
# 3                    [Closed, HigherPrice, HigherETA]     25/08/2021
# 4                    [Closed, HigherPrice, HigherETA]     25/08/2021
# 5                                                  []     25/08/2021
# 6                                                  []     25/08/2021
# 7                                                  []     25/08/2021
# 8                                                  []     25/08/2021
# 9                                  [HasDriverInOffer]     25/08/2021
# 10  [Closed, HigherPrice, HasDriverInOffer, Higher...     25/08/2021
# 11                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 12                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 13                                                 []     25/08/2021
# 14                                                 []     25/08/2021
# 15                                                 []     25/08/2021
# 16                                                 []     25/08/2021
# 17                         [Closed, HasDriverInOffer]     25/08/2021
# 18            [Closed, HigherPrice, HasDriverInOffer]     25/08/2021
# 19                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 20                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 21                                                 []     25/08/2021
# 22                                                 []     25/08/2021
# 23                                                 []     25/08/2021
# 24                                                 []     25/08/2021
# 25                                 [HasDriverInOffer]     25/08/2021
# 26  [Closed, HigherPrice, HasDriverInOffer, Higher...     25/08/2021
# 27                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 28                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 29                                                 []     25/08/2021
# 30                                                 []     25/08/2021
# 31                                                 []     25/08/2021
# 32                                                 []     25/08/2021
# 33                                 [HasDriverInOffer]     25/08/2021
# 34  [Closed, HigherPrice, HasDriverInOffer, Higher...     25/08/2021
# 35                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 36                   [Closed, HigherPrice, HigherETA]     25/08/2021
# 37                                                 []     25/08/2021
# 38                                                 []     25/08/2021
# 39                                                 []     25/08/2021

# %%
csv_filename = "CuratedOffers.csv"
df_extracted.to_csv(csv_filename, index=False)

# %% [markdown]
# ### 4. DynamicPriceOption (file 2)

# %%
df_dynamicPrice = df[df['EventName'] == 'DynamicPrice_Result']
df_dynamicPrice.head()
# Out:
#            EnqueuedTimeUtc            EventName  \
# 0  2021-09-05 08:04:08 UTC  DynamicPrice_Result
# 1  2021-08-18 11:43:23 UTC  DynamicPrice_Result
# 2  2021-09-05 09:04:04 UTC  DynamicPrice_Result
# 4  2021-09-05 08:03:28 UTC  DynamicPrice_Result
# 5  2021-08-18 11:44:00 UTC  DynamicPrice_Result
#
#                                              Payload
# 0  {"provider":"ApplyDynamicPriceRange","offerId"...
# 1  {"provider":"ApplyDynamicPricePerOption","offe...
# 2  {"provider":"ApplyDynamicPriceRange","offerId"...
# 4  {"provider":"ApplyDynamicPriceRange","offerId"...
# 5  {"provider":"ApplyDynamicPricePerOption","offe...

# %%
import json
import pandas as pd

def extract_dynamic_price_details(df):
    extracted_data = []

    for _, row in df.iterrows():
        # Convert date format to DD/MM/YY
        enqueued_time_sp = pd.to_datetime(row['EnqueuedTimeUtc']).strftime('%d/%m/%y')
        
        # Ensure Payload is properly parsed
        payload_row = row['Payload']
        if isinstance(payload_row, str):  # Convert if it's a string
            payload_row = json.loads(payload_row)
        
        if isinstance(payload_row, dict) and payload_row.get("provider") == "ApplyDynamicPricePerOption":
            provider = f"\"{payload_row['provider']}\""
            offer_id = f"\"{payload_row['offerId']}\""

            for unique_option in payload_row.get("algorithmOutput", []):  # Handle missing keys safely
                price_option = {
                    "Provider": provider,
                    "OfferId": offer_id,
                    "UniqueOptionId": f"\"{unique_option.get('uniqueOptionId', '')}\"",
                    "BestPrice": unique_option.get("bestPrice", 0),  # Default to 0 if missing
                    "EnqueuedTimeSP": enqueued_time_sp
                }
                extracted_data.append(price_option)

    return pd.DataFrame(extracted_data)

# Apply function
df_dynamicPrice_extracted = extract_dynamic_price_details(df_dynamicPrice)
df_dynamicPrice_extracted
# Out:
#                         Provider                                 OfferId  \
# 0   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 1   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 2   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 3   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 4   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 5   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 6   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 7   "ApplyDynamicPricePerOption"  "56e0702c-0218-4626-8d3d-ae9d54b4503b"
# 8   "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 9   "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 10  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 11  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 12  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 13  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 14  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 15  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 16  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 17  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 18  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 19  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 20  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 21  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 22  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 23  "ApplyDynamicPricePerOption"  "00991873-194e-4a6e-89c9-8f68668b6aaa"
# 24  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 25  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 26  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 27  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 28  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 29  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 30  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 31  "ApplyDynamicPricePerOption"  "7a471a13-7922-4e7a-9667-9b2f96b44a2a"
# 32  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 33  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 34  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 35  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 36  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 37  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 38  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 39  "ApplyDynamicPricePerOption"  "7cb20a39-c7f9-4c4c-9d51-94dbb8c4ff07"
# 40  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 41  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 42  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 43  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 44  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 45  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 46  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 47  "ApplyDynamicPricePerOption"  "6dc306e7-7a6a-459a-a12c-400b4b3c9d37"
# 48  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 49  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 50  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 51  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 52  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 53  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 54  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
# 55  "ApplyDynamicPricePerOption"  "309e5beb-4e96-4f10-9233-e11057385c07"
#
#                             UniqueOptionId  BestPrice EnqueuedTimeSP
# 0   "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 1   "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 2   "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 3   "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 4   "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 5   "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 6   "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 7   "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21
# 8   "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 9   "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 10  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 11  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 12  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 13  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 14  "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 15  "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21
# 16  "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 17  "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 18  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 19  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 20  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 21  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 22  "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 23  "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21
# 24  "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 25  "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 26  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 27  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 28  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 29  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 30  "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 31  "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21
# 32  "9c4ec643-934f-56d1-198d-46a8adc6c405"      93.50       18/08/21
# 33  "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      93.50       18/08/21
# 34  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      93.50       18/08/21
# 35  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.40       18/08/21
# 36  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.40       18/08/21
# 37  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      94.40       18/08/21
# 38  "577e4bbd-f49d-ac23-56a6-e70072a05229"      94.40       18/08/21
# 39  "f9b876ab-2590-952f-d69d-5b352ec251f3"      93.95       18/08/21
# 40  "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 41  "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 42  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 43  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 44  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 45  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 46  "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 47  "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21
# 48  "b0e296a9-0590-f0e0-8211-243a2ededb12"      92.45       18/08/21
# 49  "d6562c24-0b37-5fb4-8275-65b7b8b47b87"      92.45       18/08/21
# 50  "8d0f9262-f543-d0c8-a869-33985ae3ecda"      92.45       18/08/21
# 51  "151e59ac-761a-96f5-d2b9-882037a9fd28"      94.60       18/08/21
# 52  "3cd346f4-d297-7568-2e50-d43a8e2fd0a9"      94.60       18/08/21
# 53  "b7a7b6d1-4dae-7392-5aaf-f3369c29db1d"      93.00       18/08/21
# 54  "577e4bbd-f49d-ac23-56a6-e70072a05229"      93.00       18/08/21
# 55  "f9b876ab-2590-952f-d69d-5b352ec251f3"      91.35       18/08/21

# %%
csv_filename = "DynamicPriceOptions.csv"
df_extracted.to_csv(csv_filename, index=False)

# %% [markdown]
# ### 5. DynamicPriceRange (file 3)

# %%
import json
import pandas as pd
from datetime import datetime, timedelta

def extract_dynamic_price_range(df):
    extracted_data = []

    for _, row in df.iterrows():
        # Convert timestamp to Brazilian timezone (UTC-3) and format as DD/MM/YYYY
        enqueued_time_sp = (pd.to_datetime(row['EnqueuedTimeUtc']) - timedelta(hours=3)).strftime('%d/%m/%Y')
        
        # Parse payload
        payload_row = row['Payload']
        if isinstance(payload_row, str):  # Convert if it's a string
            payload_row = json.loads(payload_row)
        
        if isinstance(payload_row, dict) and payload_row.get("provider") == "ApplyDynamicPriceRange":
            provider = f"\"{payload_row['provider']}\""
            offer_id = f"\"{payload_row['offerId']}\""
            
            # Extract relevant fields
            min_global = payload_row.get("minGlobal", 0)
            min_recommended = payload_row.get("minRecommended", 0)
            max_recommended = payload_row.get("maxRecommended", 0)
            diff_min_recommend_min_theory = payload_row.get("differenceMinRecommendMinTheory", 0)
            
            price_range_data = {
                "Provider": provider,
                "OfferId": offer_id,
                "MinGlobal": min_global,
                "MinRecommended": min_recommended,
                "MaxRecommended": max_recommended,
                "DifferenceMinRecommendMinTheory": diff_min_recommend_min_theory,
                "EnqueuedTimeSP": enqueued_time_sp
            }
            
            extracted_data.append(price_range_data)

    return pd.DataFrame(extracted_data)

# Apply function
df_dynamicPriceRange_extracted = extract_dynamic_price_range(df_dynamicPrice)
df_dynamicPriceRange_extracted
# Out:
#                     Provider                                 OfferId  \
# 0   "ApplyDynamicPriceRange"  "a6611d55-9624-4381-8cdd-323ee3689241"
# 1   "ApplyDynamicPriceRange"  "b8c636fa-8241-47dc-ac40-bdf438a04d9c"
# 2   "ApplyDynamicPriceRange"  "3d32f7fb-396d-4d3f-b673-dea1f7dc41b7"
# 3   "ApplyDynamicPriceRange"  "329194f3-95a4-45ef-b3d0-2796f74ce2a0"
# 4   "ApplyDynamicPriceRange"  "fdcfde5c-113d-4a59-9ae0-8bc31e2943d8"
# 5   "ApplyDynamicPriceRange"  "27bbc4fa-2388-4780-b66c-92a51397d191"
# 6   "ApplyDynamicPriceRange"  "baffc30b-7642-45fe-a2ce-da31a71732ae"
# 7   "ApplyDynamicPriceRange"  "b5982abd-f602-47ac-b45a-bb43bf993d46"
# 8   "ApplyDynamicPriceRange"  "f6643886-4a0f-45ae-ae32-ee95c72ee94a"
# 9   "ApplyDynamicPriceRange"  "16a2d492-b1c3-40ec-970f-b8704d8db96f"
# 10  "ApplyDynamicPriceRange"  "e94cf567-d77a-4874-9663-0b49d19f604c"
# 11  "ApplyDynamicPriceRange"  "57a52d66-93fb-40a4-b44a-662d439ce070"
# 12  "ApplyDynamicPriceRange"  "0474ba06-1a1e-4ebe-934f-b416dd0c9313"
# 13  "ApplyDynamicPriceRange"  "a48a4485-1add-468e-9f20-5b3659498b82"
# 14  "ApplyDynamicPriceRange"  "d7739a03-c1f8-46db-971f-1a9af3dd88d9"
# 15  "ApplyDynamicPriceRange"  "4e44bf19-62ff-4d6e-8ce6-f4de80bb027d"
# 16  "ApplyDynamicPriceRange"  "3da3a438-3fd3-432a-a778-e0a2d815f831"
# 17  "ApplyDynamicPriceRange"  "bc8a4008-eef4-4059-8264-a078f618f3bd"
# 18  "ApplyDynamicPriceRange"  "36d3b55c-a449-4ab3-9b49-849d158038da"
# 19  "ApplyDynamicPriceRange"  "5ebc735e-7445-4d17-aeca-b56d8d04a51a"
# 20  "ApplyDynamicPriceRange"  "31cc86f1-881b-4b89-838e-bffdcfded61e"
# 21  "ApplyDynamicPriceRange"  "7e7f25c6-6352-40d0-bd1e-1dd4e8a5c222"
# 22  "ApplyDynamicPriceRange"  "c0b7cf25-62d1-4f3d-be18-3825c316ed8d"
# 23  "ApplyDynamicPriceRange"  "de8394da-020c-422a-890a-0d77a5f8359a"
# 24  "ApplyDynamicPriceRange"  "92269c83-9103-4ea3-b93b-ae2f1762f720"
#
#     MinGlobal  MinRecommended  MaxRecommended  \
# 0           0               0               0
# 1           0               0               0
# 2           0               0               0
# 3           0               0               0
# 4           0               0               0
# 5           0               0               0
# 6           0               0               0
# 7           0               0               0
# 8           0               0               0
# 9           0               0               0
# 10          0               0               0
# 11          0               0               0
# 12          0               0               0
# 13          0               0               0
# 14          0               0               0
# 15          0               0               0
# 16          0               0               0
# 17          0               0               0
# 18          0               0               0
# 19          0               0               0
# 20          0               0               0
# 21          0               0               0
# 22          0               0               0
# 23          0               0               0
# 24          0               0               0
#
#     DifferenceMinRecommendMinTheory EnqueuedTimeSP
# 0                                 0     05/09/2021
# 1                                 0     05/09/2021
# 2                                 0     05/09/2021
# 3                                 0     05/09/2021
# 4                                 0     05/09/2021
# 5                                 0     05/09/2021
# 6                                 0     05/09/2021
# 7                                 0     05/09/2021
# 8                                 0     05/09/2021
# 9                                 0     05/09/2021
# 10                                0     05/09/2021
# 11                                0     05/09/2021
# 12                                0     05/09/2021
# 13                                0     05/09/2021
# 14                                0     05/09/2021
# 15                                0     05/09/2021
# 16                                0     05/09/2021
# 17                                0     05/09/2021
# 18                                0     05/09/2021
# 19                                0     05/09/2021
# 20                                0     05/09/2021
# 21                                0     05/09/2021
# 22                                0     05/09/2021
# 23                                0     05/09/2021
# 24                                0     05/09/2021

# %%
csv_filename = "DynamicPriceRange.csv"
df_extracted.to_csv(csv_filename, index=False)
